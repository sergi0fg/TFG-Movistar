# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import json
import os

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.decomposition import TruncatedSVD, PCA
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

# Encontrar el codo
from kneed import KneeLocator
from scipy.sparse import hstack

from ipywidgets import interact, widgets
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 15
#      12 from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
#      14 # Encontrar el codo
# ---> 15 from kneed import KneeLocator
#      16 from scipy.sparse import hstack
#      18 from ipywidgets import interact, widgets
#
# ModuleNotFoundError: No module named 'kneed'

# %%
file_path = os.path.join("/Users/sergio/Desktop/TFG-Movistar/src/JupiterNotebook/datos/movies.dat")

# Verifica si el archivo existe
if os.path.exists(file_path):
    try:
        movies = pd.read_csv(file_path, sep="\t", engine="python", header=0, encoding="ISO-8859-1",
                             names=["MovieID", "Title", "imdbID", "spanishTitle", "imdbPictureURL", "year",
                                    "rtID", "rtAllCriticsRating", "rtAllCriticsNumReviews", "rtAllCriticsNumFresh",
                                    "rtAllCriticsNumRotten", "rtAllCriticsScore", "rtTopCriticsRating", "rtTopCriticsNumReviews",
                                    "rtTopCriticsNumFresh", "rtTopCriticsNumRotten", "rtTopCriticsScore", "rtAudienceRating",
                                    "rtAudienceNumRatings", "rtAudienceScore", "rtPictureURL"])
        print("Archivo cargado correctamente.")
    except Exception as e:
        print(f"Error al cargar el archivo: {e}")
else:
    print("El archivo no existe en la ruta especificada.")

# %%
movies.shape

# %%
movies

# %%
#Devolver una tupla que contiene el número de filas y el número de columnas en el DataFrame.
movies.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 #Devolver una tupla que contiene el número de filas y el número de columnas en el DataFrame.
# ----> 2 movies.shape
#
# NameError: name 'movies' is not defined

# %%
movies
# Out:
#        MovieID                        Title   imdbID  \
# 0            1                    Toy story   114709
# 1            2                      Jumanji   113497
# 2            3               Grumpy Old Men   107050
# 3            4            Waiting to Exhale   114885
# 4            5  Father of the Bride Part II   113041
# ...        ...                          ...      ...
# 10192    65088              Bedtime Stories   960731
# 10193    65091          Manhattan Melodrama    25464
# 10194    65126                        Choke  1024715
# 10195    65130           Revolutionary Road   959337
# 10196    65133      Blackadder Back & Forth   212579
#
#                                             spanishTitle  \
# 0                                   Toy story (juguetes)
# 1                                                Jumanji
# 2                                    Dos viejos gruñones
# 3                                   Esperando un respiro
# 4      Vuelve el padre de la novia (Ahora también abu...
# ...                                                  ...
# 10192                             Más allá de los sueños
# 10193                        El enemigo público número 1
# 10194                                              Choke
# 10195                                 Revolutionary Road
# 10196                            Blackadder Back & Forth
#
#                                           imdbPictureURL  year  \
# 0      http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995
# 1      http://ia.media-imdb.com/images/M/MV5BMzM5NjE1...  1995
# 2      http://ia.media-imdb.com/images/M/MV5BMTI5MTgy...  1993
# 3      http://ia.media-imdb.com/images/M/MV5BMTczMTMy...  1995
# 4      http://ia.media-imdb.com/images/M/MV5BMTg1NDc2...  1995
# ...                                                  ...   ...
# 10192  http://ia.media-imdb.com/images/M/MV5BMjA5Njk5...  2008
# 10193  http://ia.media-imdb.com/images/M/MV5BMTUyODE3...  1934
# 10194  http://ia.media-imdb.com/images/M/MV5BMTMxMDI4...  2008
# 10195  http://ia.media-imdb.com/images/M/MV5BMTI2MzY2...  2008
# 10196  http://ia.media-imdb.com/images/M/MV5BMjA5MjU4...  1999
#
#                               rtID rtAllCriticsRating rtAllCriticsNumReviews  \
# 0                        toy_story                  9                     73
# 1                  1068044-jumanji                5.6                     28
# 2                   grumpy_old_men                5.9                     36
# 3                waiting_to_exhale                5.6                     25
# 4      father_of_the_bride_part_ii                5.3                     19
# ...                            ...                ...                    ...
# 10192              bedtime_stories                4.4                    104
# 10193          manhattan_melodrama                  7                     12
# 10194                        choke                5.6                    135
# 10195           revolutionary_road                6.7                    194
# 10196        blackadder-back-forth                  0                      0
#
#       rtAllCriticsNumFresh  ... rtAllCriticsScore rtTopCriticsRating  \
# 0                       73  ...               100                8.5
# 1                       13  ...                46                5.8
# 2                       24  ...                66                  7
# 3                       14  ...                56                5.5
# 4                        9  ...                47                5.4
# ...                    ...  ...               ...                ...
# 10192                   26  ...                25                4.7
# 10193                   10  ...                83                  0
# 10194                   73  ...                54                4.9
# 10195                  133  ...                68                6.9
# 10196                    0  ...                 0                  0
#
#       rtTopCriticsNumReviews rtTopCriticsNumFresh rtTopCriticsNumRotten  \
# 0                         17                   17                     0
# 1                          5                    2                     3
# 2                          6                    5                     1
# 3                         11                    5                     6
# 4                          5                    1                     4
# ...                      ...                  ...                   ...
# 10192                     26                    6                    20
# 10193                      4                    2                     2
# 10194                     26                    8                    18
# 10195                     36                   25                    11
# 10196                      0                    0                     0
#
#       rtTopCriticsScore rtAudienceRating rtAudienceNumRatings rtAudienceScore  \
# 0                   100              3.7               102338              81
# 1                    40              3.2                44587              61
# 2                    83              3.2                10489              66
# 3                    45              3.3                 5666              79
# 4                    20                3                13761              64
# ...                 ...              ...                  ...             ...
# 10192                23              3.5               108877              63
# 10193                50              3.7                  344              71
# 10194                30              3.3                13893              55
# 10195                69              3.5                46044              70
# 10196                 0                0                    0               0
#
#                                             rtPictureURL
# 0      http://content7.flixster.com/movie/10/93/63/10...
# 1      http://content8.flixster.com/movie/56/79/73/56...
# 2      http://content6.flixster.com/movie/25/60/25602...
# 3      http://content9.flixster.com/movie/10/94/17/10...
# 4      http://content8.flixster.com/movie/25/54/25542...
# ...                                                  ...
# 10192  http://content6.flixster.com/movie/10/94/33/10...
# 10193  http://content9.flixster.com/movie/66/44/64/66...
# 10194  http://content6.flixster.com/movie/10/85/09/10...
# 10195  http://content8.flixster.com/movie/10/88/40/10...
# 10196  http://content7.flixster.com/movie/34/10/69/34...
#
# [10197 rows x 21 columns]

# %%
# Visualizar las primeras filas para asegurarnos de que se haya cargado correctamente
movies.head()
# Out:
#    MovieID                        Title  imdbID  \
# 0        1                    Toy story  114709
# 1        2                      Jumanji  113497
# 2        3               Grumpy Old Men  107050
# 3        4            Waiting to Exhale  114885
# 4        5  Father of the Bride Part II  113041
#
#                                         spanishTitle  \
# 0                               Toy story (juguetes)
# 1                                            Jumanji
# 2                                Dos viejos gruñones
# 3                               Esperando un respiro
# 4  Vuelve el padre de la novia (Ahora también abu...
#
#                                       imdbPictureURL  year  \
# 0  http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995
# 1  http://ia.media-imdb.com/images/M/MV5BMzM5NjE1...  1995
# 2  http://ia.media-imdb.com/images/M/MV5BMTI5MTgy...  1993
# 3  http://ia.media-imdb.com/images/M/MV5BMTczMTMy...  1995
# 4  http://ia.media-imdb.com/images/M/MV5BMTg1NDc2...  1995
#
#                           rtID rtAllCriticsRating rtAllCriticsNumReviews  \
# 0                    toy_story                  9                     73
# 1              1068044-jumanji                5.6                     28
# 2               grumpy_old_men                5.9                     36
# 3            waiting_to_exhale                5.6                     25
# 4  father_of_the_bride_part_ii                5.3                     19
#
#   rtAllCriticsNumFresh  ... rtAllCriticsScore rtTopCriticsRating  \
# 0                   73  ...               100                8.5
# 1                   13  ...                46                5.8
# 2                   24  ...                66                  7
# 3                   14  ...                56                5.5
# 4                    9  ...                47                5.4
#
#   rtTopCriticsNumReviews rtTopCriticsNumFresh rtTopCriticsNumRotten  \
# 0                     17                   17                     0
# 1                      5                    2                     3
# 2                      6                    5                     1
# 3                     11                    5                     6
# 4                      5                    1                     4
#
#   rtTopCriticsScore rtAudienceRating rtAudienceNumRatings rtAudienceScore  \
# 0               100              3.7               102338              81
# 1                40              3.2                44587              61
# 2                83              3.2                10489              66
# 3                45              3.3                 5666              79
# 4                20                3                13761              64
#
#                                         rtPictureURL
# 0  http://content7.flixster.com/movie/10/93/63/10...
# 1  http://content8.flixster.com/movie/56/79/73/56...
# 2  http://content6.flixster.com/movie/25/60/25602...
# 3  http://content9.flixster.com/movie/10/94/17/10...
# 4  http://content8.flixster.com/movie/25/54/25542...
#
# [5 rows x 21 columns]

# %%
movies.columns
# Out:
# Index(['MovieID', 'Title', 'imdbID', 'spanishTitle', 'imdbPictureURL', 'year',
#        'rtID', 'rtAllCriticsRating', 'rtAllCriticsNumReviews',
#        'rtAllCriticsNumFresh', 'rtAllCriticsNumRotten', 'rtAllCriticsScore',
#        'rtTopCriticsRating', 'rtTopCriticsNumReviews', 'rtTopCriticsNumFresh',
#        'rtTopCriticsNumRotten', 'rtTopCriticsScore', 'rtAudienceRating',
#        'rtAudienceNumRatings', 'rtAudienceScore', 'rtPictureURL'],
#       dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10197 entries, 0 to 10196
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MovieID                 10197 non-null  int64
#  1   Title                   10197 non-null  object
#  2   imdbID                  10197 non-null  int64
#  3   spanishTitle            10197 non-null  object
#  4   imdbPictureURL          10016 non-null  object
#  5   year                    10197 non-null  int64
#  6   rtID                    9886 non-null   object
#  7   rtAllCriticsRating      10197 non-null  object
#  8   rtAllCriticsNumReviews  10197 non-null  object
#  9   rtAllCriticsNumFresh    10197 non-null  object
#  10  rtAllCriticsNumRotten   10197 non-null  object
#  11  rtAllCriticsScore       10197 non-null  object
#  12  rtTopCriticsRating      10197 non-null  object
#  13  rtTopCriticsNumReviews  10197 non-null  object
#  14  rtTopCriticsNumFresh    10197 non-null  object
#  15  rtTopCriticsNumRotten   10197 non-null  object
#  16  rtTopCriticsScore       10197 non-null  object
#  17  rtAudienceRating        10197 non-null  object
#  18  rtAudienceNumRatings    10197 non-null  object
#  19  rtAudienceScore         10197 non-null  object
#  20  rtPictureURL            10197 non-null  object
# dtypes: int64(3), object(18)
# memory usage: 1.6+ MB

# %%
movies.describe()
# Out:
#             MovieID        imdbID          year
# count  10197.000000  1.019700e+04  10197.000000
# mean   12852.741002  2.021885e+05   1988.251643
# std    17431.004896  2.071287e+05     18.688734
# min        1.000000  4.390000e+02   1903.000000
# 25%     2780.000000  8.220000e+04   1981.000000
# 50%     5421.000000  1.130570e+05   1995.000000
# 75%     8664.000000  2.817240e+05   2002.000000
# max    65133.000000  1.349938e+06   2011.000000

# %%
movies.describe(include="object")
# Out:
#                            Title spanishTitle  \
# count                      10197        10197
# unique                      9406         9357
# top     The Phantom of the Opera       Hamlet
# freq                           6            6
#
#                                            imdbPictureURL            rtID  \
# count                                               10016            9886
# unique                                               9221            9134
# top     http://ia.media-imdb.com/images/M/MV5BMTc1MzQ0...  1075422-hamlet
# freq                                                    6               6
#
#        rtAllCriticsRating rtAllCriticsNumReviews rtAllCriticsNumFresh  \
# count               10197                  10197                10197
# unique                 86                    244                  205
# top                     0                      0                    0
# freq                 1526                    655                 1050
#
#        rtAllCriticsNumRotten rtAllCriticsScore rtTopCriticsRating  \
# count                  10197             10197              10197
# unique                   150               101                 82
# top                        0                 0                  0
# freq                    1555              1053               5305
#
#        rtTopCriticsNumReviews rtTopCriticsNumFresh rtTopCriticsNumRotten  \
# count                   10197                10197                 10197
# unique                     49                   44                    39
# top                         0                    0                     0
# freq                     2461                 3530                  3951
#
#        rtTopCriticsScore rtAudienceRating rtAudienceNumRatings  \
# count              10197            10197                10197
# unique                98               34                 5087
# top                    0                0                    0
# freq                3530             2622                 2622
#
#        rtAudienceScore rtPictureURL
# count            10197        10197
# unique              89         9152
# top                  0           \N
# freq              2625          230

# %% [markdown]
# Comprobación de duplicados

# %%
movies.rtID.value_counts()
# Out:
# 1075422-hamlet              6
# phantom_of_the_opera        5
# doa_dead_or_alive           4
# punisher_war_zone           4
# king_kong                   4
#                            ..
# thing_called_love           1
# wasabi                      1
# big_bully                   1
# bound_for_glory             1
# the-big-day-jour-de-fete    1
# Name: rtID, Length: 9134, dtype: int64

# %% [markdown]
# Vemos filas repetidas, vamos a eliminar las muestras repetidas

# %%
movies[movies.rtID == '1075422-hamlet']
# Out:
#       MovieID   Title  imdbID spanishTitle  \
# 1284     1411  Hamlet  116477       Hamlet
# 1735     1941  Hamlet  116477       Hamlet
# 2589     2820  Hamlet  116477       Hamlet
# 3319     3598  Hamlet  116477       Hamlet
# 3441     3723  Hamlet  116477       Hamlet
# 9986    61246  Hamlet  116477       Hamlet
#
#                                          imdbPictureURL  year            rtID  \
# 1284  http://ia.media-imdb.com/images/M/MV5BMTM5NjMz...  1996  1075422-hamlet
# 1735  http://ia.media-imdb.com/images/M/MV5BMTM5NjMz...  1996  1075422-hamlet
# 2589  http://ia.media-imdb.com/images/M/MV5BMTM5NjMz...  1996  1075422-hamlet
# 3319  http://ia.media-imdb.com/images/M/MV5BMTM5NjMz...  1996  1075422-hamlet
# 3441  http://ia.media-imdb.com/images/M/MV5BMTM5NjMz...  1996  1075422-hamlet
# 9986  http://ia.media-imdb.com/images/M/MV5BMTM5NjMz...  1996  1075422-hamlet
#
#      rtAllCriticsRating rtAllCriticsNumReviews rtAllCriticsNumFresh  ...  \
# 1284                8.2                     54                   51  ...
# 1735                8.2                     54                   51  ...
# 2589                8.2                     54                   51  ...
# 3319                8.2                     54                   51  ...
# 3441                8.2                     54                   51  ...
# 9986                8.2                     54                   51  ...
#
#      rtAllCriticsScore rtTopCriticsRating rtTopCriticsNumReviews  \
# 1284                94                7.2                     14
# 1735                94                7.2                     14
# 2589                94                7.2                     14
# 3319                94                7.2                     14
# 3441                94                7.2                     14
# 9986                94                7.2                     14
#
#      rtTopCriticsNumFresh rtTopCriticsNumRotten rtTopCriticsScore  \
# 1284                   11                     3                78
# 1735                   11                     3                78
# 2589                   11                     3                78
# 3319                   11                     3                78
# 3441                   11                     3                78
# 9986                   11                     3                78
#
#      rtAudienceRating rtAudienceNumRatings rtAudienceScore  \
# 1284              3.8                 5816              86
# 1735              3.8                 5816              86
# 2589              3.8                 5816              86
# 3319              3.8                 5816              86
# 3441              3.8                 5816              86
# 9986              3.8                 5816              86
#
#                                            rtPictureURL
# 1284  http://content7.flixster.com/movie/10/94/26/10...
# 1735  http://content7.flixster.com/movie/10/94/26/10...
# 2589  http://content7.flixster.com/movie/10/94/26/10...
# 3319  http://content7.flixster.com/movie/10/94/26/10...
# 3441  http://content7.flixster.com/movie/10/94/26/10...
# 9986  http://content7.flixster.com/movie/10/94/26/10...
#
# [6 rows x 21 columns]

# %% [markdown]
# La columna que identifica de manera unica las peliculas es la de MovieID y la de imdbID

# %%
# Contar el número total de duplicados únicos basados en las columnas 'Title' y 'year'
movieid_duplicates = movies.duplicated(subset=['MovieID']).sum()

print(f"Total de duplicados: {movieid_duplicates}")
# Out:
# Total de duplicados: 0

# %%
# Contar el número total de duplicados únicos basados en las columnas 'Title' y 'year'
num_duplicates = movies.duplicated(subset=['imdbID']).sum()

print(f"Total de duplicados: {num_duplicates}")
# Out:
# Total de duplicados: 774

# %% [markdown]
# Vemos que el campo MovieID cambia por peliculas iguales, vamos a eliminar los duplicados segun la columna imdbID

# %%
movies.shape
# Out:
# (10197, 21)

# %%
# Especificar las columnas para la eliminación de duplicados
columns_to_check = ['imdbID']

# Eliminar filas duplicadas
df_no_duplicates = movies.drop_duplicates(subset=columns_to_check)

print("\nDataFrame después de eliminar filas duplicadas:")
print(df_no_duplicates)
# Out:
# DataFrame después de eliminar filas duplicadas:
#        MovieID                        Title   imdbID  \
# 0            1                    Toy story   114709
# 1            2                      Jumanji   113497
# 2            3               Grumpy Old Men   107050
# 3            4            Waiting to Exhale   114885
# 4            5  Father of the Bride Part II   113041
# ...        ...                          ...      ...
# 10191    65037                        Ben X   953318
# 10192    65088              Bedtime Stories   960731
# 10193    65091          Manhattan Melodrama    25464
# 10194    65126                        Choke  1024715
# 10196    65133      Blackadder Back & Forth   212579
#
#                                             spanishTitle  \
# 0                                   Toy story (juguetes)
# 1                                                Jumanji
# 2                                    Dos viejos gruñones
# 3                                   Esperando un respiro
# 4      Vuelve el padre de la novia (Ahora también abu...
# ...                                                  ...
# 10191                                              Ben X
# 10192                             Más allá de los sueños
# 10193                        El enemigo público número 1
# 10194                                              Choke
# 10196                            Blackadder Back & Forth
#
#                                           imdbPictureURL  year  \
# 0      http://ia.media-imdb.com/images/M/MV5BMTMwNDU0...  1995
# 1      http://ia.media-imdb.com/images/M/MV5BMzM5NjE1...  1995
# 2      http://ia.media-imdb.com/images/M/MV5BMTI5MTgy...  1993
# 3      http://ia.media-imdb.com/images/M/MV5BMTczMTMy...  1995
# 4      http://ia.media-imdb.com/images/M/MV5BMTg1NDc2...  1995
# ...                                                  ...   ...
# 10191  http://ia.media-imdb.com/images/M/MV5BMTkxMDMy...  2007
# 10192  http://ia.media-imdb.com/images/M/MV5BMjA5Njk5...  2008
# 10193  http://ia.media-imdb.com/images/M/MV5BMTUyODE3...  1934
# 10194  http://ia.media-imdb.com/images/M/MV5BMTMxMDI4...  2008
# 10196  http://ia.media-imdb.com/images/M/MV5BMjA5MjU4...  1999
#
#                               rtID rtAllCriticsRating rtAllCriticsNumReviews  \
# 0                        toy_story                  9                     73
# 1                  1068044-jumanji                5.6                     28
# 2                   grumpy_old_men                5.9                     36
# 3                waiting_to_exhale                5.6                     25
# 4      father_of_the_bride_part_ii                5.3                     19
# ...                            ...                ...                    ...
# 10191               10009212-ben_x                6.3                     36
# 10192              bedtime_stories                4.4                    104
# 10193          manhattan_melodrama                  7                     12
# 10194                        choke                5.6                    135
# 10196        blackadder-back-forth                  0                      0
#
#       rtAllCriticsNumFresh  ... rtAllCriticsScore rtTopCriticsRating  \
# 0                       73  ...               100                8.5
# 1                       13  ...                46                5.8
# 2                       24  ...                66                  7
# 3                       14  ...                56                5.5
# 4                        9  ...                47                5.4
# ...                    ...  ...               ...                ...
# 10191                   24  ...                66                6.1
# 10192                   26  ...                25                4.7
# 10193                   10  ...                83                  0
# 10194                   73  ...                54                4.9
# 10196                    0  ...                 0                  0
#
#       rtTopCriticsNumReviews rtTopCriticsNumFresh rtTopCriticsNumRotten  \
# 0                         17                   17                     0
# 1                          5                    2                     3
# 2                          6                    5                     1
# 3                         11                    5                     6
# 4                          5                    1                     4
# ...                      ...                  ...                   ...
# 10191                      7                    4                     3
# 10192                     26                    6                    20
# 10193                      4                    2                     2
# 10194                     26                    8                    18
# 10196                      0                    0                     0
#
#       rtTopCriticsScore rtAudienceRating rtAudienceNumRatings rtAudienceScore  \
# 0                   100              3.7               102338              81
# 1                    40              3.2                44587              61
# 2                    83              3.2                10489              66
# 3                    45              3.3                 5666              79
# 4                    20                3                13761              64
# ...                 ...              ...                  ...             ...
# 10191                57              3.9                 2886              82
# 10192                23              3.5               108877              63
# 10193                50              3.7                  344              71
# 10194                30              3.3                13893              55
# 10196                 0                0                    0               0
#
#                                             rtPictureURL
# 0      http://content7.flixster.com/movie/10/93/63/10...
# 1      http://content8.flixster.com/movie/56/79/73/56...
# 2      http://content6.flixster.com/movie/25/60/25602...
# 3      http://content9.flixster.com/movie/10/94/17/10...
# 4      http://content8.flixster.com/movie/25/54/25542...
# ...                                                  ...
# 10191  http://content9.flixster.com/movie/10/86/82/10...
# 10192  http://content6.flixster.com/movie/10/94/33/10...
# 10193  http://content9.flixster.com/movie/66/44/64/66...
# 10194  http://content6.flixster.com/movie/10/85/09/10...
# 10196  http://content7.flixster.com/movie/34/10/69/34...
#
# [9423 rows x 21 columns]

# %%
df_no_duplicates.shape
# Out:
# (9423, 21)

# %%
df_no_duplicates.rtID.value_counts()
# Out:
# crying_game                      1
# my_neighbor_totoro               1
# uncle_buck                       1
# tropic_thunder                   1
# national_lampoons_senior_trip    1
#                                 ..
# 1015844-owl_and_the_pussycat     1
# mambo_kings                      1
# waitress                         1
# dead_mary                        1
# the-big-day-jour-de-fete         1
# Name: rtID, Length: 9126, dtype: int64

# %% [markdown]
# Comprobación de nulos

# %%
df_no_duplicates.isnull().sum()
# Out:
# MovieID                     0
# Title                       0
# imdbID                      0
# spanishTitle                0
# imdbPictureURL            176
# year                        0
# rtID                      297
# rtAllCriticsRating          0
# rtAllCriticsNumReviews      0
# rtAllCriticsNumFresh        0
# rtAllCriticsNumRotten       0
# rtAllCriticsScore           0
# rtTopCriticsRating          0
# rtTopCriticsNumReviews      0
# rtTopCriticsNumFresh        0
# rtTopCriticsNumRotten       0
# rtTopCriticsScore           0
# rtAudienceRating            0
# rtAudienceNumRatings        0
# rtAudienceScore             0
# rtPictureURL                0
# dtype: int64

# %% [markdown]
# Sólo hay nulos en las columnas imdbPictureURL, y rtID

# %% [markdown]
# - Columna imdbPictureURL
#
# Como es una columna que muestra la imagen de la pelicula y no nos sirve para el clustering la podemos eliminar

# %%
# Eliminar la columna 'rating'
df_no_duplicates = df_no_duplicates.drop(columns=['imdbPictureURL'])

# %% [markdown]
# - Columna rtID

# %%
df_no_duplicates.rtID.value_counts()
# Out:
# crying_game                      1
# my_neighbor_totoro               1
# uncle_buck                       1
# tropic_thunder                   1
# national_lampoons_senior_trip    1
#                                 ..
# 1015844-owl_and_the_pussycat     1
# mambo_kings                      1
# waitress                         1
# dead_mary                        1
# the-big-day-jour-de-fete         1
# Name: rtID, Length: 9126, dtype: int64

# %%
df_no_duplicates = df_no_duplicates.drop(columns=['rtID'])

# %%
df_no_duplicates.isnull().sum()
# Out:
# MovieID                   0
# Title                     0
# imdbID                    0
# spanishTitle              0
# year                      0
# rtAllCriticsRating        0
# rtAllCriticsNumReviews    0
# rtAllCriticsNumFresh      0
# rtAllCriticsNumRotten     0
# rtAllCriticsScore         0
# rtTopCriticsRating        0
# rtTopCriticsNumReviews    0
# rtTopCriticsNumFresh      0
# rtTopCriticsNumRotten     0
# rtTopCriticsScore         0
# rtAudienceRating          0
# rtAudienceNumRatings      0
# rtAudienceScore           0
# rtPictureURL              0
# dtype: int64

# %%
movies = df_no_duplicates

# %%
movies.isnull().sum()
# Out:
# MovieID                   0
# Title                     0
# imdbID                    0
# spanishTitle              0
# year                      0
# rtAllCriticsRating        0
# rtAllCriticsNumReviews    0
# rtAllCriticsNumFresh      0
# rtAllCriticsNumRotten     0
# rtAllCriticsScore         0
# rtTopCriticsRating        0
# rtTopCriticsNumReviews    0
# rtTopCriticsNumFresh      0
# rtTopCriticsNumRotten     0
# rtTopCriticsScore         0
# rtAudienceRating          0
# rtAudienceNumRatings      0
# rtAudienceScore           0
# rtPictureURL              0
# dtype: int64

# %% [markdown]
# ### Análisis exploratorio

# %%
# Visualizar la distribución de algunas variables
plt.figure(figsize=(10, 6))
sns.histplot(movies['year'], bins=30, kde=True)
plt.title('Distribución del Año de Lanzamiento')
plt.show()

# %%
# Distribución del rating de todos los críticos (Rotten Tomatoes) con ajustes en el eje X
plt.figure(figsize=(20, 6))
sns.histplot(movies['rtAllCriticsRating'], bins=30, kde=True)
plt.title('Distribución del Rating de Todos los Críticos (Rotten Tomatoes)')
plt.xticks(rotation=45)  # Inclinar las etiquetas del eje X 45 grados
plt.show()

# %% [markdown]
# Vamos a convertir las variables de tipo rating o score a numericas. Las que tengan valores de \N lo convierte a null

# %%
movies.dtypes
# Out:
# MovieID                    int64
# Title                     object
# imdbID                     int64
# spanishTitle              object
# year                       int64
# rtAllCriticsRating        object
# rtAllCriticsNumReviews    object
# rtAllCriticsNumFresh      object
# rtAllCriticsNumRotten     object
# rtAllCriticsScore         object
# rtTopCriticsRating        object
# rtTopCriticsNumReviews    object
# rtTopCriticsNumFresh      object
# rtTopCriticsNumRotten     object
# rtTopCriticsScore         object
# rtAudienceRating          object
# rtAudienceNumRatings      object
# rtAudienceScore           object
# rtPictureURL              object
# dtype: object

# %%
print(movies['rtAllCriticsRating'].dtype)
# Out:
# object

# %%
movies['rtAllCriticsRating'] = pd.to_numeric(movies['rtAllCriticsRating'], errors='coerce')

# %%
print(movies['rtAllCriticsRating'].dtype)
# Out:
# float64

# %%
print(movies['rtAllCriticsRating'].head())
# Out:
# 0    9.0
# 1    5.6
# 2    5.9
# 3    5.6
# 4    5.3
# Name: rtAllCriticsRating, dtype: float64

# %%
# Distribución del rating de todos los críticos (Rotten Tomatoes) con ajustes en el eje X
plt.figure(figsize=(10, 6))
sns.histplot(movies['rtAllCriticsRating'], bins=30, kde=True)
plt.title('Distribución del Rating de Todos los Críticos (Rotten Tomatoes)')
plt.xticks(rotation=45)  # Inclinar las etiquetas del eje X 45 grados
plt.show()

# %%
movies['rtAllCriticsRating'] = pd.to_numeric(movies['rtAllCriticsRating'], errors='coerce')

# %%
movies.rtAllCriticsNumReviews.value_counts()
# Out:
# 0      610
# 5      278
# 7      268
# 6      264
# 9      249
#       ...
# 257      1
# 220      1
# 251      1
# 254      1
# 227      1
# Name: rtAllCriticsNumReviews, Length: 244, dtype: int64

# %%
movies['rtAllCriticsNumReviews'] = pd.to_numeric(movies['rtAllCriticsNumReviews'], errors='coerce')

# %%
movies.dtypes
# Out:
# MovieID                     int64
# Title                      object
# imdbID                      int64
# spanishTitle               object
# year                        int64
# rtAllCriticsRating        float64
# rtAllCriticsNumReviews    float64
# rtAllCriticsNumFresh       object
# rtAllCriticsNumRotten      object
# rtAllCriticsScore          object
# rtTopCriticsRating         object
# rtTopCriticsNumReviews     object
# rtTopCriticsNumFresh       object
# rtTopCriticsNumRotten      object
# rtTopCriticsScore          object
# rtAudienceRating           object
# rtAudienceNumRatings       object
# rtAudienceScore            object
# rtPictureURL               object
# dtype: object

# %%
movies['rtAllCriticsNumReviews'] = movies['rtAllCriticsNumReviews'].astype('Int64')

# %%
# Distribución del rating de todos los críticos (Rotten Tomatoes) con ajustes en el eje X
plt.figure(figsize=(10, 6))
sns.histplot(movies['rtAllCriticsNumReviews'], bins=30, kde=True)
plt.title('Distribución del Numero de reviews de Todos los Críticos (Rotten Tomatoes)')
plt.xticks(rotation=45)  # Inclinar las etiquetas del eje X 45 grados
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-144-4ed97ee74de7> in <module>
#       1 # Distribución del rating de todos los críticos (Rotten Tomatoes) con ajustes en el eje X
#       2 plt.figure(figsize=(10, 6))
# ----> 3 sns.histplot(movies['rtAllCriticsNumReviews'], bins=30, kde=True)
#       4 plt.title('Distribución del Numero de reviews de Todos los Críticos (Rotten Tomatoes)')
#       5 plt.xticks(rotation=45)  # Inclinar las etiquetas del eje X 45 grados
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1420     if p.univariate:
#    1421
# -> 1422         p.plot_univariate_histogram(
#    1423             multiple=multiple,
#    1424             element=element,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     412             kde_kws["cumulative"] = estimate_kws["cumulative"]
#     413             log_scale = self._log_scaled(self.data_variable)
# --> 414             densities = self._compute_univariate_density(
#     415                 self.data_variable,
#     416                 common_norm,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py in _compute_univariate_density(self, data_variable, common_norm, common_grid, estimate_kws, log_scale)
#     313
#     314             # Estimate the density of observations at this level
# --> 315             density, support = estimator(observations, weights=weights)
#     316
#     317             if log_scale:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_statistics.py in __call__(self, x1, x2, weights)
#     185         """Fit and evaluate on univariate or bivariate data."""
#     186         if x2 is None:
# --> 187             return self._eval_univariate(x1, weights)
#     188         else:
#     189             return self._eval_bivariate(x1, x2, weights)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_statistics.py in _eval_univariate(self, x, weights)
#     144         support = self.support
#     145         if support is None:
# --> 146             support = self.define_support(x, cache=False)
#     147
#     148         kde = self._fit(x, weights)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_statistics.py in define_support(self, x1, x2, weights, cache)
#     117         """Create the evaluation grid for a given data set."""
#     118         if x2 is None:
# --> 119             support = self._define_support_univariate(x1, weights)
#     120         else:
#     121             support = self._define_support_bivariate(x1, x2, weights)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_statistics.py in _define_support_univariate(self, x, weights)
#      89     def _define_support_univariate(self, x, weights):
#      90         """Create a 1D grid of evaluation points."""
# ---> 91         kde = self._fit(x, weights)
#      92         bw = np.sqrt(kde.covariance.squeeze())
#      93         grid = self._define_support_grid(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_statistics.py in _fit(self, fit_data, weights)
#     135             fit_kws["weights"] = weights
#     136
# --> 137         kde = stats.gaussian_kde(fit_data, **fit_kws)
#     138         kde.set_bandwidth(kde.factor * self.bw_adjust)
#     139
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/kde.py in __init__(self, dataset, bw_method, weights)
#     204             self._neff = 1/sum(self._weights**2)
#     205
# --> 206         self.set_bandwidth(bw_method=bw_method)
#     207
#     208     def evaluate(self, points):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/kde.py in set_bandwidth(self, bw_method)
#     554             raise ValueError(msg)
#     555
# --> 556         self._compute_covariance()
#     557
#     558     def _compute_covariance(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/kde.py in _compute_covariance(self)
#     563         # Cache covariance and inverse covariance of the data
#     564         if not hasattr(self, '_data_inv_cov'):
# --> 565             self._data_covariance = atleast_2d(cov(self.dataset, rowvar=1,
#     566                                                bias=False,
#     567                                                aweights=self.weights))
#
# <__array_function__ internals> in cov(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2454             w *= aweights
#    2455
# -> 2456     avg, w_sum = average(X, axis=1, weights=w, returned=True)
#    2457     w_sum = w_sum[0]
#    2458
#
# <__array_function__ internals> in average(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in average(a, axis, weights, returned)
#     405             wgt = wgt.swapaxes(-1, axis)
#     406
# --> 407         scl = wgt.sum(axis=axis, dtype=result_dtype)
#     408         if np.any(scl == 0.0):
#     409             raise ZeroDivisionError(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      46          initial=_NoValue, where=True):
# ---> 47     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      48
#      49 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: No loop matching the specified signature and casting was found for ufunc add

# %%
movies.dtypes
# Out:
# MovieID                     int64
# Title                      object
# imdbID                      int64
# spanishTitle               object
# year                        int64
# rtAllCriticsRating        float64
# rtAllCriticsNumReviews      Int64
# rtAllCriticsNumFresh       object
# rtAllCriticsNumRotten      object
# rtAllCriticsScore          object
# rtTopCriticsRating         object
# rtTopCriticsNumReviews     object
# rtTopCriticsNumFresh       object
# rtTopCriticsNumRotten      object
# rtTopCriticsScore          object
# rtAudienceRating           object
# rtAudienceNumRatings       object
# rtAudienceScore            object
# rtPictureURL               object
# dtype: object

# %%
movies.rtAllCriticsNumFresh.value_counts()
# Out:
# 0      986
# 1      472
# 2      438
# 3      415
# 4      369
#       ...
# 181      1
# 206      1
# 194      1
# 192      1
# 172      1
# Name: rtAllCriticsNumFresh, Length: 205, dtype: int64

# %%
movies.rtAllCriticsNumRotten.value_counts()
# Out:
# 0      1457
# 1       964
# 2       769
# 3       624
# 4       518
#        ...
# 160       1
# 127       1
# 157       1
# 135       1
# 162       1
# Name: rtAllCriticsNumRotten, Length: 150, dtype: int64

# %%
movies.rtAllCriticsScore.value_counts()
# Out:
# 0      987
# 100    847
# 50     273
# \N     220
# 66     217
#       ...
# 98      21
# 5       19
# 49      16
# 2        7
# 1        6
# Name: rtAllCriticsScore, Length: 101, dtype: int64

# %%
movies.rtTopCriticsRating.value_counts()
# Out:
# 0      5065
# \N      220
# 5.8     111
# 6.2     109
# 5.2     109
#        ...
# 9.4       1
# 1.6       1
# 10        1
# 9.7       1
# 9.8       1
# Name: rtTopCriticsRating, Length: 82, dtype: int64

# %%
movies.rtTopCriticsNumReviews.value_counts()
# Out:
# 0     2349
# 1     1001
# 2      671
# 3      584
# 4      460
# 5      395
# 6      315
# 7      242
# \N     220
# 8      177
# 9      151
# 11     135
# 10     131
# 30     122
# 12     113
# 32     112
# 29     110
# 31     108
# 27      99
# 26      97
# 13      96
# 34      96
# 28      95
# 35      95
# 24      94
# 33      94
# 25      92
# 14      90
# 23      83
# 22      82
# 19      81
# 17      81
# 21      77
# 15      75
# 20      74
# 37      72
# 36      71
# 16      71
# 18      66
# 38      57
# 39      54
# 40      49
# 41      33
# 42      21
# 43      18
# 44      10
# 45       2
# 48       1
# 47       1
# Name: rtTopCriticsNumReviews, dtype: int64

# %%
movies.rtTopCriticsNumFresh.value_counts()
# Out:
# 0     3373
# 1     1173
# 2      762
# 3      550
# 4      443
# 5      316
# 6      274
# 7      228
# \N     220
# 8      193
# 9      154
# 10     144
# 11     124
# 13     119
# 12     105
# 14      97
# 16      87
# 15      86
# 17      75
# 23      73
# 18      73
# 19      71
# 20      68
# 22      68
# 21      61
# 25      56
# 24      53
# 28      47
# 26      43
# 29      41
# 27      37
# 30      35
# 33      27
# 31      26
# 35      21
# 32      21
# 36      18
# 38      15
# 37      14
# 34      10
# 39       8
# 40       7
# 41       5
# 42       2
# Name: rtTopCriticsNumFresh, dtype: int64

# %%
movies.rtTopCriticsNumRotten.value_counts()
# Out:
# 0     3747
# 1     1475
# 2      760
# 3      527
# 4      343
# 5      254
# \N     220
# 6      203
# 7      179
# 8      145
# 9      140
# 11     115
# 12     109
# 10     105
# 14     101
# 13      97
# 15      93
# 16      91
# 18      78
# 19      70
# 17      69
# 20      67
# 22      67
# 21      65
# 23      51
# 26      44
# 24      43
# 25      41
# 27      28
# 28      25
# 29      18
# 30      15
# 32      13
# 31       9
# 34       5
# 33       4
# 35       3
# 36       3
# 38       1
# Name: rtTopCriticsNumRotten, dtype: int64

# %%
movies.rtTopCriticsScore.value_counts()
# Out:
# 0      3373
# 100    1398
# 50      490
# 66      259
# \N      220
#        ...
# 3        12
# 74       11
# 39       10
# 79        8
# 2         3
# Name: rtTopCriticsScore, Length: 98, dtype: int64

# %%
movies.rtAudienceRating.value_counts()
# Out:
# 0      2504
# 3.4     524
# 3.3     516
# 3.6     514
# 3.2     511
# 3.5     510
# 3.1     471
# 3.7     456
# 3       451
# 3.8     382
# 3.9     381
# 2.9     355
# 4       303
# 2.8     288
# 4.1     225
# \N      220
# 2.7     194
# 2.6     148
# 4.2     134
# 2.5      92
# 4.3      83
# 2.4      44
# 4.4      40
# 2.3      26
# 2.2      17
# 2.1      11
# 4.5      11
# 2         4
# 4.6       3
# 5         1
# 1.8       1
# 1.9       1
# 1.6       1
# 1.5       1
# Name: rtAudienceRating, dtype: int64

# %%
movies.rtAudienceNumRatings.value_counts()
# Out:
# 0         2504
# \N         220
# 289          8
# 281          7
# 530          6
#           ...
# 1305         1
# 56344        1
# 1577         1
# 1448         1
# 267474       1
# Name: rtAudienceNumRatings, Length: 5080, dtype: int64

# %%
movies.rtAudienceScore.value_counts()
# Out:
# 0     2507
# \N     220
# 73     155
# 79     144
# 70     144
#       ...
# 14       2
# 98       2
# 17       2
# 11       1
# 15       1
# Name: rtAudienceScore, Length: 89, dtype: int64

# %%
movies['rtAllCriticsNumFresh'] = pd.to_numeric(movies['rtAllCriticsNumFresh'], errors='coerce')
movies['rtAllCriticsNumRotten'] = pd.to_numeric(movies['rtAllCriticsNumRotten'], errors='coerce')

movies['rtAllCriticsNumFresh'] = movies['rtAllCriticsNumFresh'].astype('Int64')
movies['rtAllCriticsNumRotten'] = movies['rtAllCriticsNumRotten'].astype('Int64')

# %%
movies['rtAllCriticsScore'] = pd.to_numeric(movies['rtAllCriticsScore'], errors='coerce')
movies['rtAllCriticsScore'] = movies['rtAllCriticsScore'].astype('Int64')

# %%
movies['rtTopCriticsRating'] = pd.to_numeric(movies['rtTopCriticsRating'], errors='coerce')

movies['rtTopCriticsNumReviews'] = pd.to_numeric(movies['rtTopCriticsNumReviews'], errors='coerce')
movies['rtTopCriticsNumReviews'] = movies['rtTopCriticsNumReviews'].astype('Int64')

movies['rtTopCriticsNumFresh'] = pd.to_numeric(movies['rtTopCriticsNumFresh'], errors='coerce')
movies['rtTopCriticsNumFresh'] = movies['rtTopCriticsNumFresh'].astype('Int64')

movies['rtTopCriticsNumRotten'] = pd.to_numeric(movies['rtTopCriticsNumRotten'], errors='coerce')
movies['rtTopCriticsNumRotten'] = movies['rtTopCriticsNumRotten'].astype('Int64')

movies['rtTopCriticsScore'] = pd.to_numeric(movies['rtTopCriticsScore'], errors='coerce')
movies['rtTopCriticsScore'] = movies['rtTopCriticsScore'].astype('Int64')

movies['rtAudienceRating'] = pd.to_numeric(movies['rtAudienceRating'], errors='coerce')

movies['rtAudienceNumRatings'] = pd.to_numeric(movies['rtAudienceNumRatings'], errors='coerce')
movies['rtAudienceNumRatings'] = movies['rtAudienceNumRatings'].astype('Int64')

movies['rtAudienceScore'] = pd.to_numeric(movies['rtAudienceScore'], errors='coerce')
movies['rtAudienceScore'] = movies['rtAudienceScore'].astype('Int64')

# %%
print(movies[["rtAllCriticsRating", "rtAllCriticsNumReviews", "rtAllCriticsNumFresh",
                            "rtAllCriticsNumRotten", "rtAllCriticsScore", "rtTopCriticsRating", "rtTopCriticsNumReviews",
                            "rtTopCriticsNumFresh", "rtTopCriticsNumRotten", "rtTopCriticsScore", "rtAudienceRating",
                            "rtAudienceNumRatings", "rtAudienceScore"]].head())
# Out:
#    rtAllCriticsRating  rtAllCriticsNumReviews  rtAllCriticsNumFresh  \
# 0                 9.0                      73                    73
# 1                 5.6                      28                    13
# 2                 5.9                      36                    24
# 3                 5.6                      25                    14
# 4                 5.3                      19                     9
#
#    rtAllCriticsNumRotten  rtAllCriticsScore  rtTopCriticsRating  \
# 0                      0                100                 8.5
# 1                     15                 46                 5.8
# 2                     12                 66                 7.0
# 3                     11                 56                 5.5
# 4                     10                 47                 5.4
#
#    rtTopCriticsNumReviews  rtTopCriticsNumFresh  rtTopCriticsNumRotten  \
# 0                      17                    17                      0
# 1                       5                     2                      3
# 2                       6                     5                      1
# 3                      11                     5                      6
# 4                       5                     1                      4
#
#    rtTopCriticsScore  rtAudienceRating  rtAudienceNumRatings  rtAudienceScore
# 0                100               3.7                102338               81
# 1                 40               3.2                 44587               61
# 2                 83               3.2                 10489               66
# 3                 45               3.3                  5666               79
# 4                 20               3.0                 13761               64

# %%
movies.isna().sum() #movies.isnull().sum()
# Out:
# MovieID                     0
# Title                       0
# imdbID                      0
# spanishTitle                0
# year                        0
# rtAllCriticsRating        220
# rtAllCriticsNumReviews    220
# rtAllCriticsNumFresh      220
# rtAllCriticsNumRotten     220
# rtAllCriticsScore         220
# rtTopCriticsRating        220
# rtTopCriticsNumReviews    220
# rtTopCriticsNumFresh      220
# rtTopCriticsNumRotten     220
# rtTopCriticsScore         220
# rtAudienceRating          220
# rtAudienceNumRatings      220
# rtAudienceScore           220
# rtPictureURL                0
# dtype: int64

# %%
movies.shape
# Out:
# (9423, 19)

# %%
df_no_na = movies.dropna()

# %%
df_no_na.isna().sum()
# Out:
# MovieID                   0
# Title                     0
# imdbID                    0
# spanishTitle              0
# year                      0
# rtAllCriticsRating        0
# rtAllCriticsNumReviews    0
# rtAllCriticsNumFresh      0
# rtAllCriticsNumRotten     0
# rtAllCriticsScore         0
# rtTopCriticsRating        0
# rtTopCriticsNumReviews    0
# rtTopCriticsNumFresh      0
# rtTopCriticsNumRotten     0
# rtTopCriticsScore         0
# rtAudienceRating          0
# rtAudienceNumRatings      0
# rtAudienceScore           0
# rtPictureURL              0
# dtype: int64

# %%
movies.shape
# Out:
# (9423, 19)

# %%
# Función para mostrar gráficos de barras para variables categóricas
def plot_categorical_distribution(df, column):
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df, x=column)
    plt.title(f'Distribución de {column}')
    plt.xticks(rotation=90)
    plt.show()

# %%
# Función para mostrar histogramas para variables numéricas
def plot_numerical_distribution(df, column):
    plt.figure(figsize=(10, 6))
    sns.histplot(df[column], bins=30, kde=True)
    plt.title(f'Distribución de {column}')
    plt.show()

# %%
movies = df_no_na

# %%
# Distribución del año de lanzamiento
plot_numerical_distribution(movies, 'year')

# %%
# Distribución del rating de todos los críticos (Rotten Tomatoes)
plot_numerical_distribution(movies, 'rtAllCriticsRating')

# %%
#Distribución del número de reseñas de todos los críticos (Rotten Tomatoes)
plot_numerical_distribution(movies, 'rtAllCriticsNumReviews')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-933974615f66> in <module>
#       1 #Distribución del número de reseñas de todos los críticos (Rotten Tomatoes)
# ----> 2 plot_numerical_distribution(movies, 'rtAllCriticsNumReviews')
#
# <ipython-input-83-41336ed61012> in plot_numerical_distribution(df, column)
#       2 def plot_numerical_distribution(df, column):
#       3     plt.figure(figsize=(10, 6))
# ----> 4     sns.histplot(df[column], bins=30, kde=True)
#       5     plt.title(f'Distribución de {column}')
#       6     plt.show()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1420     if p.univariate:
#    1421
# -> 1422         p.plot_univariate_histogram(
#    1423             multiple=multiple,
#    1424             element=element,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     412             kde_kws["cumulative"] = estimate_kws["cumulative"]
#     413             log_scale = self._log_scaled(self.data_variable)
# --> 414             densities = self._compute_univariate_density(
#     415                 self.data_variable,
#     416                 common_norm,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py in _compute_univariate_density(self, data_variable, common_norm, common_grid, estimate_kws, log_scale)
#     313
#     314             # Estimate the density of observations at this level
# --> 315             density, support = estimator(observations, weights=weights)
#     316
#     317             if log_scale:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_statistics.py in __call__(self, x1, x2, weights)
#     185         """Fit and evaluate on univariate or bivariate data."""
#     186         if x2 is None:
# --> 187             return self._eval_univariate(x1, weights)
#     188         else:
#     189             return self._eval_bivariate(x1, x2, weights)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_statistics.py in _eval_univariate(self, x, weights)
#     144         support = self.support
#     145         if support is None:
# --> 146             support = self.define_support(x, cache=False)
#     147
#     148         kde = self._fit(x, weights)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_statistics.py in define_support(self, x1, x2, weights, cache)
#     117         """Create the evaluation grid for a given data set."""
#     118         if x2 is None:
# --> 119             support = self._define_support_univariate(x1, weights)
#     120         else:
#     121             support = self._define_support_bivariate(x1, x2, weights)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_statistics.py in _define_support_univariate(self, x, weights)
#      89     def _define_support_univariate(self, x, weights):
#      90         """Create a 1D grid of evaluation points."""
# ---> 91         kde = self._fit(x, weights)
#      92         bw = np.sqrt(kde.covariance.squeeze())
#      93         grid = self._define_support_grid(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_statistics.py in _fit(self, fit_data, weights)
#     135             fit_kws["weights"] = weights
#     136
# --> 137         kde = stats.gaussian_kde(fit_data, **fit_kws)
#     138         kde.set_bandwidth(kde.factor * self.bw_adjust)
#     139
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/kde.py in __init__(self, dataset, bw_method, weights)
#     204             self._neff = 1/sum(self._weights**2)
#     205
# --> 206         self.set_bandwidth(bw_method=bw_method)
#     207
#     208     def evaluate(self, points):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/kde.py in set_bandwidth(self, bw_method)
#     554             raise ValueError(msg)
#     555
# --> 556         self._compute_covariance()
#     557
#     558     def _compute_covariance(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/kde.py in _compute_covariance(self)
#     563         # Cache covariance and inverse covariance of the data
#     564         if not hasattr(self, '_data_inv_cov'):
# --> 565             self._data_covariance = atleast_2d(cov(self.dataset, rowvar=1,
#     566                                                bias=False,
#     567                                                aweights=self.weights))
#
# <__array_function__ internals> in cov(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2454             w *= aweights
#    2455
# -> 2456     avg, w_sum = average(X, axis=1, weights=w, returned=True)
#    2457     w_sum = w_sum[0]
#    2458
#
# <__array_function__ internals> in average(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in average(a, axis, weights, returned)
#     405             wgt = wgt.swapaxes(-1, axis)
#     406
# --> 407         scl = wgt.sum(axis=axis, dtype=result_dtype)
#     408         if np.any(scl == 0.0):
#     409             raise ZeroDivisionError(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      46          initial=_NoValue, where=True):
# ---> 47     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      48
#      49 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: No loop matching the specified signature and casting was found for ufunc add

# %%
#Distribución del número de reseñas de todos los críticos (Rotten Tomatoes)
plot_numerical_distribution(movies, 'rtAllCriticsScore')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-d3cf214d3a55> in <module>
#       1 #Distribución del número de reseñas de todos los críticos (Rotten Tomatoes)
# ----> 2 plot_numerical_distribution(movies, 'rtAllCriticsScore')
#
# <ipython-input-83-41336ed61012> in plot_numerical_distribution(df, column)
#       2 def plot_numerical_distribution(df, column):
#       3     plt.figure(figsize=(10, 6))
# ----> 4     sns.histplot(df[column], bins=30, kde=True)
#       5     plt.title(f'Distribución de {column}')
#       6     plt.show()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1420     if p.univariate:
#    1421
# -> 1422         p.plot_univariate_histogram(
#    1423             multiple=multiple,
#    1424             element=element,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     412             kde_kws["cumulative"] = estimate_kws["cumulative"]
#     413             log_scale = self._log_scaled(self.data_variable)
# --> 414             densities = self._compute_univariate_density(
#     415                 self.data_variable,
#     416                 common_norm,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py in _compute_univariate_density(self, data_variable, common_norm, common_grid, estimate_kws, log_scale)
#     313
#     314             # Estimate the density of observations at this level
# --> 315             density, support = estimator(observations, weights=weights)
#     316
#     317             if log_scale:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_statistics.py in __call__(self, x1, x2, weights)
#     185         """Fit and evaluate on univariate or bivariate data."""
#     186         if x2 is None:
# --> 187             return self._eval_univariate(x1, weights)
#     188         else:
#     189             return self._eval_bivariate(x1, x2, weights)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_statistics.py in _eval_univariate(self, x, weights)
#     144         support = self.support
#     145         if support is None:
# --> 146             support = self.define_support(x, cache=False)
#     147
#     148         kde = self._fit(x, weights)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_statistics.py in define_support(self, x1, x2, weights, cache)
#     117         """Create the evaluation grid for a given data set."""
#     118         if x2 is None:
# --> 119             support = self._define_support_univariate(x1, weights)
#     120         else:
#     121             support = self._define_support_bivariate(x1, x2, weights)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_statistics.py in _define_support_univariate(self, x, weights)
#      89     def _define_support_univariate(self, x, weights):
#      90         """Create a 1D grid of evaluation points."""
# ---> 91         kde = self._fit(x, weights)
#      92         bw = np.sqrt(kde.covariance.squeeze())
#      93         grid = self._define_support_grid(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_statistics.py in _fit(self, fit_data, weights)
#     135             fit_kws["weights"] = weights
#     136
# --> 137         kde = stats.gaussian_kde(fit_data, **fit_kws)
#     138         kde.set_bandwidth(kde.factor * self.bw_adjust)
#     139
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/kde.py in __init__(self, dataset, bw_method, weights)
#     204             self._neff = 1/sum(self._weights**2)
#     205
# --> 206         self.set_bandwidth(bw_method=bw_method)
#     207
#     208     def evaluate(self, points):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/kde.py in set_bandwidth(self, bw_method)
#     554             raise ValueError(msg)
#     555
# --> 556         self._compute_covariance()
#     557
#     558     def _compute_covariance(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/kde.py in _compute_covariance(self)
#     563         # Cache covariance and inverse covariance of the data
#     564         if not hasattr(self, '_data_inv_cov'):
# --> 565             self._data_covariance = atleast_2d(cov(self.dataset, rowvar=1,
#     566                                                bias=False,
#     567                                                aweights=self.weights))
#
# <__array_function__ internals> in cov(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2454             w *= aweights
#    2455
# -> 2456     avg, w_sum = average(X, axis=1, weights=w, returned=True)
#    2457     w_sum = w_sum[0]
#    2458
#
# <__array_function__ internals> in average(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in average(a, axis, weights, returned)
#     405             wgt = wgt.swapaxes(-1, axis)
#     406
# --> 407         scl = wgt.sum(axis=axis, dtype=result_dtype)
#     408         if np.any(scl == 0.0):
#     409             raise ZeroDivisionError(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      46          initial=_NoValue, where=True):
# ---> 47     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      48
#      49 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: No loop matching the specified signature and casting was found for ufunc add

# %%
#Distribución del número de reseñas de todos los críticos (Rotten Tomatoes)
plot_numerical_distribution(movies, 'rtTopCriticsScore')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-8a3b606488fb> in <module>
#       1 #Distribución del número de reseñas de todos los críticos (Rotten Tomatoes)
# ----> 2 plot_numerical_distribution(movies, 'rtTopCriticsScore')
#
# <ipython-input-83-41336ed61012> in plot_numerical_distribution(df, column)
#       2 def plot_numerical_distribution(df, column):
#       3     plt.figure(figsize=(10, 6))
# ----> 4     sns.histplot(df[column], bins=30, kde=True)
#       5     plt.title(f'Distribución de {column}')
#       6     plt.show()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1420     if p.univariate:
#    1421
# -> 1422         p.plot_univariate_histogram(
#    1423             multiple=multiple,
#    1424             element=element,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     412             kde_kws["cumulative"] = estimate_kws["cumulative"]
#     413             log_scale = self._log_scaled(self.data_variable)
# --> 414             densities = self._compute_univariate_density(
#     415                 self.data_variable,
#     416                 common_norm,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py in _compute_univariate_density(self, data_variable, common_norm, common_grid, estimate_kws, log_scale)
#     313
#     314             # Estimate the density of observations at this level
# --> 315             density, support = estimator(observations, weights=weights)
#     316
#     317             if log_scale:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_statistics.py in __call__(self, x1, x2, weights)
#     185         """Fit and evaluate on univariate or bivariate data."""
#     186         if x2 is None:
# --> 187             return self._eval_univariate(x1, weights)
#     188         else:
#     189             return self._eval_bivariate(x1, x2, weights)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_statistics.py in _eval_univariate(self, x, weights)
#     144         support = self.support
#     145         if support is None:
# --> 146             support = self.define_support(x, cache=False)
#     147
#     148         kde = self._fit(x, weights)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_statistics.py in define_support(self, x1, x2, weights, cache)
#     117         """Create the evaluation grid for a given data set."""
#     118         if x2 is None:
# --> 119             support = self._define_support_univariate(x1, weights)
#     120         else:
#     121             support = self._define_support_bivariate(x1, x2, weights)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_statistics.py in _define_support_univariate(self, x, weights)
#      89     def _define_support_univariate(self, x, weights):
#      90         """Create a 1D grid of evaluation points."""
# ---> 91         kde = self._fit(x, weights)
#      92         bw = np.sqrt(kde.covariance.squeeze())
#      93         grid = self._define_support_grid(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_statistics.py in _fit(self, fit_data, weights)
#     135             fit_kws["weights"] = weights
#     136
# --> 137         kde = stats.gaussian_kde(fit_data, **fit_kws)
#     138         kde.set_bandwidth(kde.factor * self.bw_adjust)
#     139
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/kde.py in __init__(self, dataset, bw_method, weights)
#     204             self._neff = 1/sum(self._weights**2)
#     205
# --> 206         self.set_bandwidth(bw_method=bw_method)
#     207
#     208     def evaluate(self, points):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/kde.py in set_bandwidth(self, bw_method)
#     554             raise ValueError(msg)
#     555
# --> 556         self._compute_covariance()
#     557
#     558     def _compute_covariance(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/kde.py in _compute_covariance(self)
#     563         # Cache covariance and inverse covariance of the data
#     564         if not hasattr(self, '_data_inv_cov'):
# --> 565             self._data_covariance = atleast_2d(cov(self.dataset, rowvar=1,
#     566                                                bias=False,
#     567                                                aweights=self.weights))
#
# <__array_function__ internals> in cov(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2454             w *= aweights
#    2455
# -> 2456     avg, w_sum = average(X, axis=1, weights=w, returned=True)
#    2457     w_sum = w_sum[0]
#    2458
#
# <__array_function__ internals> in average(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in average(a, axis, weights, returned)
#     405             wgt = wgt.swapaxes(-1, axis)
#     406
# --> 407         scl = wgt.sum(axis=axis, dtype=result_dtype)
#     408         if np.any(scl == 0.0):
#     409             raise ZeroDivisionError(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      46          initial=_NoValue, where=True):
# ---> 47     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      48
#      49 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: No loop matching the specified signature and casting was found for ufunc add

# %% [markdown]
# Matriz de correlación

# %%
plt.figure(figsize=(14, 10))
corr_matrix = movies.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Matriz de Correlación')
plt.show()

# %% [markdown]
# Vemos que hay fuerte correlación entre:
# - La variable rtAudienceScore y rtAudienceRating
# - Las variables rtTopCriticsNumReviews, rtAllCriticsNumFresh y rtAllCriticsNumReviews y
# - rtTopCriticsNumFresh y rtAllCriticsNumFresh
# - rtTopCriticsNumRotten y rtAllCriticsNumRotten
# - rtAllCriticsNumRotten, rtAllCriticsNumReviews
#
# Podemos eliminar: rtAudienceScore, rtTopCriticsNumReviews, rtAllCriticsNumFresh, rtTopCriticsNumFresh, rtTopCriticsNumRotten. rtAllCriticsNumReviews

# %%
movies_2 = movies[["MovieID", "Title", "imdbID", "spanishTitle", "year",
                        "rtAllCriticsRating",
                            "rtAllCriticsNumRotten", "rtAllCriticsScore", "rtTopCriticsRating",
                            "rtTopCriticsScore", "rtAudienceRating",
                            "rtAudienceNumRatings", "rtPictureURL"]]

# %%
plt.figure(figsize=(14, 10))
corr_matrix = movies_2.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Matriz de Correlación')
plt.show()

# %%
movies_2.dtypes
# Out:
# MovieID                    int64
# Title                     object
# imdbID                     int64
# spanishTitle              object
# year                       int64
# rtAllCriticsRating       float64
# rtAllCriticsNumRotten      Int64
# rtAllCriticsScore          Int64
# rtTopCriticsRating       float64
# rtTopCriticsScore          Int64
# rtAudienceRating         float64
# rtAudienceNumRatings       Int64
# rtPictureURL              object
# dtype: object

# %%
# Diagrama de caja para algunas variables numéricas
plt.figure(figsize=(14, 10))
sns.boxplot(data=movies_2[['rtAllCriticsRating', 'rtTopCriticsRating', 'rtAudienceRating']])
plt.title('Diagrama de Caja de Ratings')
plt.show()

# %%
# Relación entre el rating de todos los críticos y el rating de la audiencia
plt.figure(figsize=(10, 6))
sns.scatterplot(data=movies_2, x='rtAllCriticsRating', y='rtAudienceRating')
plt.title('Relación entre Rating de Todos los Críticos y Rating de la Audiencia')
plt.show()

# %%
# Distribución de ratings por año de lanzamiento
plt.figure(figsize=(20, 10))
sns.boxplot(data=movies_2, x='year', y='rtAllCriticsRating')
plt.title('Distribución de Ratings de Todos los Críticos por Año de Lanzamiento')
plt.xticks(rotation=90)
plt.show()

# %%
# Distribución de ratings por año de lanzamiento
plt.figure(figsize=(20, 10))
sns.boxplot(data=movies_2, x='year', y='rtAudienceRating')
plt.title('Distribución de Ratings de Audiencia por Año de Lanzamiento')
plt.xticks(rotation=90)
plt.show()

# %%
movies_2.dtypes
# Out:
# MovieID                    int64
# Title                     object
# imdbID                     int64
# spanishTitle              object
# year                       int64
# rtAllCriticsRating       float64
# rtAllCriticsNumRotten      Int64
# rtAllCriticsScore          Int64
# rtTopCriticsRating       float64
# rtTopCriticsScore          Int64
# rtAudienceRating         float64
# rtAudienceNumRatings       Int64
# rtPictureURL              object
# dtype: object

# %%
# Seleccionar solo las columnas numéricas relevantes para el clustering
numerical_features = ['MovieID', 'imdbID','rtAllCriticsRating',                      'year','rtAllCriticsNumRotten', 'rtAllCriticsScore', 
                      'rtTopCriticsRating','rtTopCriticsScore',
                      'rtAudienceRating', 'rtAudienceNumRatings']

# %%
# Histogramas para todas las características numéricas
movies_2[numerical_features].hist(bins=30, figsize=(20, 15))
plt.suptitle('Histogramas para Características Numéricas')
plt.show()

# %%
# Pares de gráficos (pairplot) para ver las relaciones entre características numéricas
sns.pairplot(movies_2[numerical_features])
plt.suptitle('Pairplot para Características Numéricas', y=1.02)
plt.show()
